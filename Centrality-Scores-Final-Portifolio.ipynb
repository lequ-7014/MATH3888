# %%
import networkx as nx

import numpy as np
import pandas as pd
import csv

import pyvis.network

# %% [markdown]
# ## Read in Edgelist

# %%
yeast_file = "yeast_network.txt"

G_exp = nx.read_edgelist(yeast_file,comments="#",nodetype=str)

# %% [markdown]
# ## Read in CSV

# %%
clusters = []
csv_reader = csv.reader(open("dpclus_complexes.csv"))
for cluster in csv_reader:
    clusters.append(cluster)

# %%
clusters
# Out:
# [['YDR500C',
#   'YGR148C',
#   'YIL052C',
#   'YOL120C',
#   'YLR167W',
#   'YKL180W',
#   'YDR447C',
#   'YPL143W',
#   'YNL002C',
#   'YLR325C',
#   'YPR132W',
#   'YHR141C',
#   'YBL087C',
#   'YBL027W',
#   'YKR057W',
#   'YOR298C-A',
#   'YHR203C',
#   'YOL121C',
#   'YLR029C',
#   'YFR031C-A',
#   'YOR167C',
#   'YGL135W',
#   'YHL033C',
#   'YML063W',
#   'YLR264W',
#   'YLR150W',
#   'YOL040C',
#   'YOR096W',
#   'YPL249C-A',
#   'YPR102C',
#   'YMR242C',
#   'YGL076C',
#   'YMR121C',
#   'YBR181C',
#   'YNL067W',
#   'YOR312C',
#   'YNL255C',
#   'YLR048W',
#   'YJR145C',
#   'YJL136C',
#   'YJL189W',
#   'YML024W',
#   'YLR388W',
#   'YGR034W',
#   'YIL148W',
#   'YPL131W',
#   'YGL031C',
#   'YBR048W',
#   'YNL001W',
#   'YLR344W',
#   'YPL198W',
#   'YDR064W',
#   'YLR287C-A',
#   'YLR185W',
#   'YNL301C',
#   'YBR189W',
#   'YGL030W',
#   'YLR249W',
#   'YBL072C',
#   'YDL191W',
#   'YGL173C',
#   'YDR012W',
#   'YER131W',
#   'YBL092W',
#   'YIR010W',
#   'YOL127W',
#   'YDR450W',
#   'YNL178W',
#   'YDL136W',
#   'YDL184C',
#   'YER074W',
#   'YJR094W-A',
#   'YHR010W',
#   'YIL069C',
#   'YPL090C',
#   'YCR031C',
#   'YDR385W',
#   'YLR340W',
#   'YMR194W',
#   'YER056C-A',
#   'YOR369C',
#   'YER117W',
#   'YDL133C-A',
#   'YGR027C',
#   'YKL006W',
#   'YHL015W',
#   'YBR084C-A',
#   'YIL133C',
#   'YJR123W',
#   'YML026C',
#   'YEL034W',
#   'YGL103W',
#   'YFR032C-A',
#   'YDL083C',
#   'YJL177W',
#   'YPR043W',
#   'YGL195W',
#   'YJL191W',
#   'YOR293W',
#   'YGR085C',
#   'YDL075W',
#   'YOR276W',
#   'YOR182C',
#   'YDL081C',
#   'YGL123W',
#   'YML073C',
#   'YLL045C',
#   'YOR063W',
#   'YBR031W',
#   'YAL036C',
#   'YGR118W',
#   'YDR418W',
#   'YIL018W',
#   'YOR198C',
#   'YKL156W',
#   'YGL189C',
#   'YAL035W',
#   'YNL162W',
#   'YMR143W',
#   'YEL054C',
#   'YOR133W',
#   'YLR448W',
#   'YBR191W',
#   'YER102W',
#   'YGL147C',
#   'YLR075W',
#   'YCL037C',
#   'YDL082W',
#   'YDR025W',
#   'YPL220W',
#   'YOR091W',
#   'YHL001W',
#   'YHR021C',
#   'YJL190C',
#   'YLR061W',
#   'YKR094C'],
#  ['YDR398W',
#   'YLR197W',
#   'YMR128W',
#   'YML093W',
#   'YOL010W',
#   'YDR449C',
#   'YJR002W',
#   'YHR203C',
#   'YGR090W',
#   'YNL232W',
#   'YMR229C',
#   'YCR057C',
#   'YEL026W',
#   'YBR181C',
#   'YHR148W',
#   'YJR145C',
#   'YDL111C',
#   'YPL266W',
#   'YDL148C',
#   'YDR299W',
#   'YBR048W',
#   'YGR158C',
#   'YLR409C',
#   'YLR186W',
#   'YDR064W',
#   'YDR339C',
#   'YNL075W',
#   'YBL072C',
#   'YDR450W',
#   'YER074W',
#   'YLR129W',
#   'YMR093W',
#   'YIL069C',
#   'YGR095C',
#   'YCR031C',
#   'YHR069C',
#   'YHR081W',
#   'YNR024W',
#   'YOL142W',
#   'YBL004W',
#   'YOL021C',
#   'YDL153C',
#   'YJL069C',
#   'YGR145W',
#   'YHR196W',
#   'YLR051C',
#   'YPL126W',
#   'YOR145C',
#   'YDR324C',
#   'YDR280W',
#   'YJR123W',
#   'YML026C',
#   'YCR035C',
#   'YJL109C',
#   'YER082C',
#   'YDL083C',
#   'YPR144C',
#   'YPR137W',
#   'YCL059C',
#   'YGR195W',
#   'YBR247C',
#   'YER127W',
#   'YLR441C',
#   'YOR310C',
#   'YGR118W',
#   'YGR128C',
#   'YKL156W',
#   'YDL014W',
#   'YMR143W',
#   'YCL031C',
#   'YIL019W',
#   'YJL050W',
#   'YER102W',
#   'YKR060W',
#   'YLR222C',
#   'YDR025W',
#   'YKL099C',
#   'YOR078W',
#   'YLR367W',
#   'YOR001W',
#   'YHR021C',
#   'YIL127C',
#   'YLL011W'],
#  ['YNR037C',
#   'YDR347W',
#   'YMR158W',
#   'YKR085C',
#   'YGR215W',
#   'YDR237W',
#   'YBL038W',
#   'YDR296W',
#   'YML009C',
#   'YPL173W',
#   'YPL013C',
#   'YCR003W',
#   'YNR022C',
#   'YDR115W',
#   'YML025C',
#   'YNL284C',
#   'YNL081C',
#   'YLR204W',
#   'YOR158W',
#   'YOL027C',
#   'YMR188C',
#   'YNL137C',
#   'YKR006C',
#   'YHL004W',
#   'YGL122C',
#   'YCR071C',
#   'YPR166C',
#   'YBR282W',
#   'YNL255C',
#   'YPR125W',
#   'YDR036C',
#   'YBR251W',
#   'YBL090W',
#   'YJL063C',
#   'YGR220C',
#   'YKL138C',
#   'YPR042C',
#   'YER050C',
#   'YEL050C',
#   'YGL129C',
#   'YIL070C',
#   'YMR193W',
#   'YBR146W',
#   'YNL016W',
#   'YMR286W',
#   'YNL252C',
#   'YNL306W',
#   'YDR494W',
#   'YMR024W',
#   'YHR147C',
#   'YDL045W-A',
#   'YHR059W',
#   'YGR076C',
#   'YIL093C',
#   'YLR439W',
#   'YLL013C',
#   'YOR150W',
#   'YDR175C',
#   'YDR041W',
#   'YDR405W',
#   'YJR101W',
#   'YNR017W',
#   'YDR337W',
#   'YCR046C',
#   'YGR084C',
#   'Q0140',
#   'YNR036C',
#   'YKL170W',
#   'YGR165W',
#   'YJR113C',
#   'YNL005C',
#   'YPL118W',
#   'YDR462W',
#   'YJL096W',
#   'YDR322W',
#   'YNL177C',
#   'YLR312W-A',
#   'YKL003C',
#   'YNL122C',
#   'YPR100W',
#   'YPL183W-A',
#   'YBR122C'],
#  ['YPL178W',
#   'YNL138W-A',
#   'YAL032C',
#   'YPL064C',
#   'YKL095W',
#   'YLR323C',
#   'YPR094W',
#   'YGL174W',
#   'YML049C',
#   'YDR482C',
#   'YDR163W',
#   'YER013W',
#   'YLR147C',
#   'YPL213W',
#   'YDL209C',
#   'YGR129W',
#   'YOR319W',
#   'YPR101W',
#   'YGR278W',
#   'YJR050W',
#   'YKL173W',
#   'YIR009W',
#   'YER029C',
#   'YHR165C',
#   'YBR188C',
#   'YPR182W',
#   'YOR159C',
#   'YBR152W',
#   'YFL017W-A',
#   'YOR308C',
#   'YDR473C',
#   'YMR288W',
#   'YDR088C',
#   'YMR240C',
#   'YBR065C',
#   'YIR005W',
#   'YJL203W',
#   'YFL039C',
#   'YER172C',
#   'YDL043C',
#   'YNR011C',
#   'YLR016C',
#   'YDL030W',
#   'YDR416W',
#   'YMR213W',
#   'YDR364C',
#   'YGR074W',
#   'YLL036C',
#   'YOR148C',
#   'YLR117C',
#   'YLR275W',
#   'YCR063W',
#   'YPL151C'],
#  ['YKL028W',
#   'YOR151C',
#   'YDL140C',
#   'YGR005C',
#   'YHR058C',
#   'YDR404C',
#   'YOR224C',
#   'YBR193C',
#   'YKR062W',
#   'YBR154C',
#   'YBL093C',
#   'YKL058W',
#   'YLR071C',
#   'YDR079C-A',
#   'YLR005W',
#   'YGL070C',
#   'YDR460W',
#   'YDR308C',
#   'YHR041C',
#   'YGL127C',
#   'YER171W',
#   'YOL135C',
#   'YPR086W',
#   'YGR104C',
#   'YJL140W',
#   'YIL021W',
#   'YOL051W',
#   'YNL030W',
#   'YBR253W',
#   'YGR186W',
#   'YOR194C',
#   'YGL043W',
#   'YNL031C',
#   'YHR143W-A',
#   'YOL005C',
#   'YER022W',
#   'YER148W',
#   'YIL143C',
#   'YPR187W',
#   'YOR210W',
#   'YPL129W',
#   'YMR112C',
#   'YKL054C',
#   'YDR311W',
#   'YPR168W',
#   'YPR056W',
#   'YNR010W',
#   'YBR009C',
#   'YPL122C',
#   'YOR174W'],
#  ['YOR293W',
#   'YBR181C',
#   'YDL075W',
#   'YLR441C',
#   'YGL123W',
#   'YMR116C',
#   'YCR031C',
#   'YML024W',
#   'YOR369C',
#   'YGL178W',
#   'YBR245C',
#   'YPL081W',
#   'YBL004W',
#   'YGR118W',
#   'YPL217C',
#   'YNL132W',
#   'YBR010W',
#   'YHL015W',
#   'YML093W',
#   'YKL156W',
#   'YGR214W',
#   'YLL013C',
#   'YBR142W',
#   'YBR048W',
#   'YLR344W',
#   'YDR064W',
#   'YMR290C',
#   'YPR042C',
#   'YHR203C',
#   'YGR090W',
#   'YOL121C',
#   'YJR123W',
#   'YJL109C',
#   'YBL072C',
#   'YJL168C',
#   'YOL040C',
#   'YKR081C',
#   'YOR096W',
#   'YDL083C',
#   'YOL127W',
#   'YBL002W',
#   'YGL122C',
#   'YJL190C',
#   'YDR450W',
#   'YNL178W',
#   'YMR229C',
#   'YBR009C',
#   'YER074W'],
#  ['YDR427W',
#   'YDR190C',
#   'YOR117W',
#   'YHR200W',
#   'YOL038W',
#   'YDL097C',
#   'YER094C',
#   'YLR167W',
#   'YER021W',
#   'YFR052W',
#   'YER012W',
#   'YOR261C',
#   'YDR457W',
#   'YJL001W',
#   'YFR010W',
#   'YIL148W',
#   'YGL048C',
#   'YOR259C',
#   'YHL030W',
#   'YLL039C',
#   'YKL145W',
#   'YPR108W',
#   'YFR004W',
#   'YIL075C',
#   'YOR157C',
#   'YDR394W',
#   'YDL147W',
#   'YFL039C',
#   'YHR027C',
#   'YGR135W',
#   'YDR363W-A',
#   'YOR362C',
#   'YPR103W',
#   'YLR233C',
#   'YGL011C',
#   'YDL007W',
#   'YPL235W',
#   'YML092C',
#   'YGR253C',
#   'YMR314W',
#   'YBL041W',
#   'YFR050C',
#   'YLR421C'],
#  ['YHR010W',
#   'YER002W',
#   'YDR412W',
#   'YIL031W',
#   'YFR001W',
#   'YDL031W',
#   'YHR066W',
#   'YAL025C',
#   'YER126C',
#   'YLR002C',
#   'YER006W',
#   'YNL061W',
#   'YMR049C',
#   'YOR272W',
#   'YNL002C',
#   'YKL009W',
#   'YKL021C',
#   'YHR052W',
#   'YCL054W',
#   'YDR496C',
#   'YLR344W',
#   'YHR197W',
#   'YMR290C',
#   'YPL211W',
#   'YHR088W',
#   'YPR016C',
#   'YLR009W',
#   'YKL172W',
#   'YDR087C',
#   'YBL028C',
#   'YGR103W',
#   'YFL002C',
#   'YPL043W',
#   'YKR081C',
#   'YOL077C',
#   'YOL127W',
#   'YNL110C',
#   'YOR206W',
#   'YPL093W',
#   'YPR144C',
#   'YGL111W',
#   'YDR060W'],
#  ['YML103C',
#   'YIL115C',
#   'YER105C',
#   'YGL092W',
#   'YMR153W',
#   'YLR335W',
#   'YMR047C',
#   'YBL078C',
#   'YDR192C',
#   'YJL061W',
#   'YKL068W',
#   'YGR119C',
#   'YPL169C',
#   'YOR098C',
#   'YIL149C',
#   'YDL088C',
#   'YJR042W',
#   'YJL041W',
#   'YJL039C',
#   'YKL057C',
#   'YLR018C',
#   'YDL207W',
#   'YLR347C',
#   'YER107C',
#   'YGL100W',
#   'YML031W',
#   'YFR002W',
#   'YBL079W',
#   'YBR194W',
#   'YDL116W',
#   'YGL172W',
#   'YKR082W',
#   'YKR095W',
#   'YAR002W',
#   'YDR159W',
#   'YMR129W',
#   'YGL122C'],
#  ['YGL187C',
#   'YLR038C',
#   'Q0045',
#   'Q0250',
#   'YEL024W',
#   'YFR033C',
#   'YNL131W',
#   'YDR119W-A',
#   'YDR529C',
#   'YML030W',
#   'YHR001W-A',
#   'YOR065W',
#   'YNL052W',
#   'YDL067C',
#   'YGR183C',
#   'YJL019W',
#   'YKR016W',
#   'YPR191W',
#   'YBL045C',
#   'YLR395C',
#   'YGL191W',
#   'YIL111W',
#   'Q0275',
#   'Q0105',
#   'YMR256C',
#   'YHR051W',
#   'YNR018W',
#   'YBL030C',
#   'YJL166W'],
#  ['YPR034W',
#   'YLR357W',
#   'YPL116W',
#   'YHR056C',
#   'YBL003C',
#   'YPR052C',
#   'YJL127C',
#   'YCR052W',
#   'YBR010W',
#   'YMR091C',
#   'YLR033W',
#   'YKR008W',
#   'YGR275W',
#   'YMR033W',
#   'YBL006C',
#   'YFR037C',
#   'YGR056W',
#   'YDR303C',
#   'YIL126W',
#   'YML127W',
#   'YLR321C',
#   'YBR009C',
#   'YCR020W-B'],
#  ['YDR254W',
#   'YCL016C',
#   'YMR078C',
#   'YML124C',
#   'YHR191C',
#   'YGR188C',
#   'YGL086W',
#   'YDR318W',
#   'YJL030W',
#   'YPL018W',
#   'YNL153C',
#   'YPR141C',
#   'YBL034C',
#   'YML094W',
#   'YEL003W',
#   'YOR349W',
#   'YJL013C',
#   'YLR200W',
#   'YEL061C',
#   'YOR026W',
#   'YPL241C',
#   'YGR078C',
#   'YER016W'],
#  ['YLR298C',
#   'YBR119W',
#   'YDL087C',
#   'YDR243C',
#   'YDR432W',
#   'YHR086W',
#   'YLR116W',
#   'YDR240C',
#   'YKL074C',
#   'YML046W',
#   'YLR147C',
#   'YIL061C',
#   'YGR013W',
#   'YER029C',
#   'YPL157W',
#   'YMR240C',
#   'YKL012W',
#   'YBR237W',
#   'YDR235W',
#   'YMR125W',
#   'YLR275W'],
#  ['YKL144C',
#   'YOR207C',
#   'YOR224C',
#   'YNR003C',
#   'YBR154C',
#   'YGR246C',
#   'YDL150W',
#   'YNL151C',
#   'YJL011C',
#   'YKR025W',
#   'YGR047C',
#   'YHR143W-A',
#   'YDR045C',
#   'YNL039W',
#   'YPR187W',
#   'YOR210W',
#   'YDR005C',
#   'YPR110C',
#   'YPR190C',
#   'YNL113W',
#   'YOR116C'],
#  ['YDR176W',
#   'YCL010C',
#   'YHR099W',
#   'YDR145W',
#   'YOL148C',
#   'YJR074W',
#   'YGL066W',
#   'YBR198C',
#   'YGL112C',
#   'YMR236W',
#   'YPL248C',
#   'YGR252W',
#   'YPL254W',
#   'YMR223W',
#   'YPL047W',
#   'YBR111W-A',
#   'YBR081C',
#   'YMR179W',
#   'YDR392W',
#   'YDR448W',
#   'YDR167W'],
#  ['YGL113W',
#   'YLR274W',
#   'YNL262W',
#   'YLR103C',
#   'YPR019W',
#   'YPR175W',
#   'YMR048W',
#   'YNL273W',
#   'YBL023C',
#   'YBR202W',
#   'YKL108W',
#   'YDR328C',
#   'YDR489W',
#   'YPR135W',
#   'YGL201C',
#   'YEL032W',
#   'YDR013W',
#   'YJL072C',
#   'YIL150C',
#   'YNL102W',
#   'YOL146W'],
#  ['YGL137W',
#   'YPL120W',
#   'YDL100C',
#   'YHL031C',
#   'YNL041C',
#   'YNL051W',
#   'YGL020C',
#   'YDR320C',
#   'YLR039C',
#   'YGL005C',
#   'YPL051W',
#   'YOL018C',
#   'YML071C',
#   'YGL054C',
#   'YDR108W',
#   'YFR051C',
#   'YLR262C',
#   'YJL004C',
#   'YBR164C',
#   'YDR137W'],
#  ['YPR036W',
#   'YMR054W',
#   'YHR060W',
#   'YCL005W-A',
#   'YDL185W',
#   'YGR106C',
#   'YEL027W',
#   'YLR447C',
#   'YBR127C',
#   'YOR270C',
#   'YKL080W',
#   'YOR332W',
#   'YGR020C',
#   'YPR170W-B',
#   'YHR026W',
#   'YHR039C-A',
#   'YGL122C',
#   'YEL051W',
#   'YPL234C'],
#  ['YMR075W',
#   'YDR225W',
#   'YBL003C',
#   'YPL082C',
#   'YGL207W',
#   'YBR245C',
#   'YJL127C',
#   'YOR244W',
#   'YDR224C',
#   'YBR010W',
#   'YER164W',
#   'YGR252W',
#   'YGR270W',
#   'YDR334W',
#   'YOL012C',
#   'YFR037C',
#   'YOR141C',
#   'YJL115W',
#   'YBR009C'],
#  ['Q0130',
#   'YJR121W',
#   'YBR039W',
#   'YKL016C',
#   'YDR298C',
#   'YML081C-A',
#   'YOL077W-A',
#   'YPL078C',
#   'YBL099W',
#   'Q0085',
#   'YLR295C',
#   'YLR393W',
#   'YDL004W',
#   'YIR024C',
#   'YKR016W',
#   'YDR377W',
#   'YPL271W',
#   'Q0080'],
#  ['YKL113C',
#   'YLR320W',
#   'YCL061C',
#   'YML032C',
#   'YBR098W',
#   'YJL047C',
#   'YLR135W',
#   'YDR510W',
#   'YJR043C',
#   'YOR144C',
#   'YER095W',
#   'YDR217C',
#   'YKL049C',
#   'YJL092W',
#   'YHR154W',
#   'YMR190C',
#   'YPR164W',
#   'YPR135W'],
#  ['YER142C',
#   'YML032C',
#   'YPL167C',
#   'YDR409W',
#   'YPL022W',
#   'YGL087C',
#   'YER095W',
#   'YCR066W',
#   'YIR002C',
#   'YDL102W',
#   'YDR419W',
#   'YLR032W',
#   'YJL092W',
#   'YGL163C',
#   'YOR346W',
#   'YDR076W',
#   'YBR088C'],
#  ['YJL025W',
#   'YJL148W',
#   'YKL125W',
#   'YOR340C',
#   'YHR143W-A',
#   'YPR010C',
#   'YDR156W',
#   'YJR063W',
#   'YNL113W',
#   'YOR341W',
#   'YML043C',
#   'YBL014C',
#   'YOR224C',
#   'YNL248C',
#   'YOR210W',
#   'YBR154C'],
#  ['YER025W',
#   'YDR429C',
#   'YJR007W',
#   'YBR181C',
#   'YLR192C',
#   'YPR041W',
#   'YDL061C',
#   'YCR031C',
#   'YPL237W',
#   'YBR079C',
#   'YMR146C',
#   'YBL072C',
#   'YMR260C',
#   'YMR309C',
#   'YBR048W',
#   'YNL244C'],
#  ['YIR025W',
#   'YDR118W',
#   'YDR260C',
#   'YHR166C',
#   'YFR036W',
#   'YGL116W',
#   'YGL003C',
#   'YKL101W',
#   'YGL240W',
#   'YBL084C',
#   'YLR102C',
#   'YDL008W',
#   'YLR127C',
#   'YOR249C',
#   'YNL172W',
#   'YKL022C'],
#  ['YDR166C',
#   'YIL068C',
#   'YGR009C',
#   'YPL232W',
#   'YBR102C',
#   'YGL233W',
#   'YLR166C',
#   'YIL118W',
#   'YPR032W',
#   'YFL005W',
#   'YJL085W',
#   'YNL272C',
#   'YNR049C',
#   'YPR055W',
#   'YDR164C',
#   'YER008C'],
#  ['YOR085W',
#   'YOR002W',
#   'YGL226C-A',
#   'YFL031W',
#   'YOR067C',
#   'YOR103C',
#   'YPL227C',
#   'YGR227W',
#   'YJL002C',
#   'YMR149W',
#   'YGL022W',
#   'YEL002C',
#   'YBL082C',
#   'YNR030W',
#   'YML019W',
#   'YNL219C'],
#  ['YNL136W',
#   'YEL018W',
#   'YJR082C',
#   'YPR023C',
#   'YJL081C',
#   'YHR099W',
#   'YDR359C',
#   'YHR090C',
#   'YDR334W',
#   'YOL012C',
#   'YAL011W',
#   'YGR002C',
#   'YFL039C',
#   'YOR244W',
#   'YNL107W',
#   'YFL024C'],
#  ['YJL122W',
#   'YHR085W',
#   'YBL087C',
#   'YBL092W',
#   'YBL027W',
#   'YGL029W',
#   'YLR074C',
#   'YGR245C',
#   'YNL182C',
#   'YLR106C',
#   'YGL099W',
#   'YBR031W',
#   'YNR053C',
#   'YDR101C',
#   'YCR072C'],
#  ['YMR061W',
#   'YNL317W',
#   'YLR115W',
#   'YKL018W',
#   'YGR156W',
#   'YAL043C',
#   'YKR002W',
#   'YLR277C',
#   'YJR093C',
#   'YDR228C',
#   'YDR195W',
#   'YNL222W',
#   'YGL044C',
#   'YDR301W',
#   'YKL059C'],
#  ['YOL147C',
#   'YMR026C',
#   'YLR191W',
#   'YDL065C',
#   'YOL044W',
#   'YDR244W',
#   'YDR265W',
#   'YNL329C',
#   'YKL197C',
#   'YNL214W',
#   'YGR077C',
#   'YJL210W',
#   'YJR089W',
#   'YGL153W'],
#  ['YOR072W-B',
#   'YDR014W',
#   'YFR027W',
#   'YJR135C',
#   'YJL074C',
#   'YDR254W',
#   'YDR318W',
#   'YLR381W',
#   'YFL008W',
#   'YBR107C',
#   'YDR180W',
#   'YDL003W',
#   'YPR046W',
#   'YPL018W'],
#  ['YJR046W',
#   'YNL261W',
#   'YPL008W',
#   'YBR060C',
#   'YPR120C',
#   'YHR118C',
#   'YPR162C',
#   'YLR274W',
#   'YJL194W',
#   'YML065W',
#   'YBL023C',
#   'YBR202W',
#   'YLL004W',
#   'YJL106W'],
#  ['YPL045W',
#   'YBR131W',
#   'YDR495C',
#   'YLR396C',
#   'YDR080W',
#   'YMR231W',
#   'YOR106W',
#   'YDL077C',
#   'YAL002W',
#   'YKR014C',
#   'YGL212W',
#   'YML001W',
#   'YLR148W',
#   'YOR089C'],
#  ['YCR068W',
#   'YBL047C',
#   'YPL149W',
#   'YBR131W',
#   'YDL149W',
#   'YLR431C',
#   'YNR007C',
#   'YGL180W',
#   'YLL042C',
#   'YFR021W',
#   'YHR171W',
#   'YBR217W',
#   'YNL223W',
#   'YPR185W'],
#  ['YLR234W',
#   'YML032C',
#   'YCL061C',
#   'YDR075W',
#   'YOL006C',
#   'YMR284W',
#   'YNL250W',
#   'YHR031C',
#   'YOR080W',
#   'YDR369C',
#   'YGL175C',
#   'YMR190C',
#   'YMR224C',
#   'YML061C'],
#  ['YNL206C',
#   'YDL220C',
#   'YOR368W',
#   'YCL061C',
#   'YAR007C',
#   'YER173W',
#   'YPL153C',
#   'YDR217C',
#   'YPL194W',
#   'YBL088C',
#   'YBR136W',
#   'YPR018W',
#   'YMR190C',
#   'YDL101C'],
#  ['YLR085C',
#   'YDL074C',
#   'YLR055C',
#   'YDR485C',
#   'YLR418C',
#   'YPL055C',
#   'YOL004W',
#   'YDL156W',
#   'YDR469W',
#   'YJR089W',
#   'YDR392W',
#   'YML041C',
#   'YBR231C',
#   'YNL097C'],
#  ['YER112W',
#   'YDL160C',
#   'YDR378C',
#   'YEL015W',
#   'YNL118C',
#   'YBL026W',
#   'YOL149W',
#   'YJR022W',
#   'YJL124C',
#   'YCR077C',
#   'YNL147W',
#   'YGL173C',
#   'YLR438C-A'],
#  ['YER157W',
#   'YFL038C',
#   'YLR268W',
#   'YDR189W',
#   'YLR078C',
#   'YOR216C',
#   'YNL041C',
#   'YLR026C',
#   'YDL058W',
#   'YBL050W',
#   'YIL004C',
#   'YGR120C',
#   'YKL196C'],
#  ['YMR218C',
#   'YEL048C',
#   'YDR472W',
#   'YKR068C',
#   'YDR407C',
#   'YML077W',
#   'YOR115C',
#   'YDR246W',
#   'YDR108W',
#   'YGL210W',
#   'YBR254C',
#   'YGR166W'],
#  ['YBR257W',
#   'YLR145W',
#   'YNL282W',
#   'YBR167C',
#   'YGR030C',
#   'YHR062C',
#   'YNL221C',
#   'YIR015W',
#   'YAL033W',
#   'YDR478W',
#   'YPR144C',
#   'YBL018C'],
#  ['YGR187C',
#   'YGL194C',
#   'YJR064W',
#   'YDR188W',
#   'YDR212W',
#   'YIL142W',
#   'YJL008C',
#   'YJL111W',
#   'YOR281C',
#   'YPL165C',
#   'YJL014W',
#   'YDL143W'],
#  ['YNR023W',
#   'YHL025W',
#   'YBR010W',
#   'YJL176C',
#   'YOR290C',
#   'YPL016W',
#   'YOR119C',
#   'YDR073W',
#   'YFL049W',
#   'YLL013C',
#   'YBL072C',
#   'YBR289W'],
#  ['YDR488C',
#   'YPL174C',
#   'YDR150W',
#   'YER016W',
#   'YPL269W',
#   'YJR053W',
#   'YNL153C',
#   'YKR054C',
#   'YLL049W',
#   'YMR294W',
#   'YHR129C',
#   'YMR055C'],
#  ['YBR211C',
#   'YIL144W',
#   'YDL028C',
#   'YGR113W',
#   'YOL069W',
#   'YFR046C',
#   'YIR010W',
#   'YKL052C',
#   'YMR117C',
#   'YGR179C',
#   'YJL030W',
#   'YGL093W'],
#  ['YGR092W',
#   'YPR119W',
#   'YAR019C',
#   'YMR001C',
#   'YGL190C',
#   'YJL076W',
#   'YAL024C',
#   'YML064C',
#   'YGR098C',
#   'YOR195W',
#   'YHR152W',
#   'YFR028C'],
#  ['YGL049C',
#   'YGL014W',
#   'YGR162W',
#   'YER165W',
#   'YJL138C',
#   'YOR204W',
#   'YDL075W',
#   'YGL123W',
#   'YOL139C',
#   'YCR031C',
#   'YIL137C',
#   'YOR361C'],
#  ['YKR037C',
#   'YKL138C-A',
#   'YDR016C',
#   'YDR201W',
#   'YDR320C-A',
#   'YGR113W',
#   'YBR156C',
#   'YIR010W',
#   'YGL061C',
#   'YKR083C',
#   'YBR233W-A'],
#  ['YNL070W',
#   'YNL121C',
#   'YMR203W',
#   'YPR133W-A',
#   'YNL131W',
#   'YHR083W',
#   'YMR060C',
#   'YKR016W',
#   'YOR045W',
#   'YGR082W',
#   'YNL026W'],
#  ['YBL093C',
#   'YGL151W',
#   'YCL028W',
#   'YDR443C',
#   'YCR081W',
#   'YDL005C',
#   'YDR308C',
#   'YNL236W',
#   'YGL025C',
#   'YPR070W',
#   'YBR253W'],
#  ['YLL014W',
#   'YBR283C',
#   'YGR157W',
#   'YGL231C',
#   'YJL192C',
#   'YDR056C',
#   'YJR088C',
#   'YCL045C',
#   'YIL027C',
#   'YKL207W',
#   'YDL020C'],
#  ['YPR072W',
#   'YNR052C',
#   'YIL038C',
#   'YDL165W',
#   'YGR134W',
#   'YAL021C',
#   'YPL037C',
#   'YCR093W',
#   'YER068W',
#   'YGR274C',
#   'YNL288W'],
#  ['YAL048C',
#   'YKL053C-A',
#   'YGR231C',
#   'YDL142C',
#   'YGR132C',
#   'YOL009C',
#   'YPL103C',
#   'YAL010C',
#   'YNL169C',
#   'YGL219C',
#   'YLL006W'],
#  ['YKL062W',
#   'YJL005W',
#   'YFL033C',
#   'YIL033C',
#   'YNL098C',
#   'YHR205W',
#   'YOL081W',
#   'YPL203W',
#   'YKL166C',
#   'YMR037C',
#   'YJL164C'],
#  ['YHR107C',
#   'YKR048C',
#   'YNL078W',
#   'YCR002C',
#   'YJR076C',
#   'YDR507C',
#   'YCL024W',
#   'YNL166C',
#   'YGL158W',
#   'YLR314C',
#   'YDL225W'],
#  ['YBR160W',
#   'YMR199W',
#   'YDL056W',
#   'YAL040C',
#   'YPL256C',
#   'YGL003C',
#   'YER167W',
#   'YER111C',
#   'YLR182W',
#   'YOR083W',
#   'YBR245C'],
#  ['YBR098W',
#   'YDR386W',
#   'YEL019C',
#   'YIR002C',
#   'YDR363W',
#   'YOL034W',
#   'YHR154W',
#   'YML023C',
#   'YLR383W',
#   'YER038C',
#   'YLR007W'],
#  ['YPL101W',
#   'YGR200C',
#   'YLR384C',
#   'YMR263W',
#   'YDL002C',
#   'YPL086C',
#   'YLL002W',
#   'YHR090C',
#   'YMR312W',
#   'YGL058W',
#   'YML028W'],
#  ['YOR181W',
#   'YKL129C',
#   'YCR009C',
#   'YJL020C',
#   'YBR234C',
#   'YBL007C',
#   'YLR337C',
#   'YHR114W',
#   'YBR108W',
#   'YDR388W',
#   'YMR109W'],
#  ['YLR319C',
#   'YHL007C',
#   'YJL187C',
#   'YHR030C',
#   'YNL298W',
#   'YLR229C',
#   'YLL021W',
#   'YER155C',
#   'YBR200W',
#   'YOR326W',
#   'YNL271C'],
#  ['YLR212C',
#   'YOR008C',
#   'YDR293C',
#   'YBL032W',
#   'YHR030C',
#   'YBR160W',
#   'YBL105C',
#   'YNL298W',
#   'YNL188W',
#   'YJL095W',
#   'YER111C'],
#  ['YCR042C',
#   'YBR198C',
#   'YML015C',
#   'YML114C',
#   'YPL011C',
#   'YDR145W',
#   'YMR227C',
#   'YML098W',
#   'YMR005W',
#   'YDR167W'],
#  ['YLR268W',
#   'YDR189W',
#   'YGL098W',
#   'YNL258C',
#   'YLR440C',
#   'YOR165W',
#   'YGL145W',
#   'YOR075W',
#   'YKL196C',
#   'YDR498C'],
#  ['YOR217W',
#   'YOR368W',
#   'YLR288C',
#   'YER173W',
#   'YNL290W',
#   'YBR087W',
#   'YOL094C',
#   'YJR068W',
#   'YDL164C',
#   'YBL035C'],
#  ['YCL011C',
#   'YDL084W',
#   'YNL139C',
#   'YNL253W',
#   'YHR167W',
#   'YDR381W',
#   'YML062C',
#   'YDR138W',
#   'YOR166C',
#   'YNL004W'],
#  ['YOR198C',
#   'YAL007C',
#   'YGL200C',
#   'YML012W',
#   'YAR002C-A',
#   'YHR110W',
#   'YOR016C',
#   'YGL122C',
#   'YDL018C',
#   'YGL002W'],
#  ['YAL058W',
#   'YDR414C',
#   'YMR200W',
#   'YBR015C',
#   'YHR101C',
#   'YJR075W',
#   'YJL034W',
#   'YMR214W',
#   'YBR229C',
#   'YOR336W'],
#  ['YGL137W',
#   'YDR372C',
#   'YIL076W',
#   'YER122C',
#   'YNL287W',
#   'YFR051C',
#   'YML067C',
#   'YDL192W',
#   'YDR238C',
#   'YDL145C'],
#  ['YAL047C',
#   'YLL003W',
#   'YNL225C',
#   'YKL042W',
#   'YPL124W',
#   'YMR117C',
#   'YHR172W',
#   'YLR045C',
#   'YFR028C',
#   'YDR356W'],
#  ['YHR030C',
#   'YDL095W',
#   'YBR015C',
#   'YAL023C',
#   'YJL062W',
#   'YGL027C',
#   'YGR166W',
#   'YBR229C',
#   'YML019W',
#   'YCR017C'],
#  ['YML069W',
#   'YJL168C',
#   'YKL139W',
#   'YOL145C',
#   'YML010W',
#   'YGR116W',
#   'YBR279W',
#   'YDL140C',
#   'YGL244W',
#   'YGR063C'],
#  ['YDR227W',
#   'YBR010W',
#   'YNL330C',
#   'YDR440W',
#   'YMR127C',
#   'YDL042C',
#   'YHR119W',
#   'YBR009C',
#   'YLR442C',
#   'YGR252W'],
#  ['YFL025C',
#   'YHR030C',
#   'YML008C',
#   'YFL031W',
#   'YMR307W',
#   'YJR073C',
#   'YGR167W',
#   'YGL084C',
#   'YCR044C',
#   'YHR079C'],
#  ['YHR156C',
#   'YDR473C',
#   'YPR178W',
#   'YDL098C',
#   'YBL026W',
#   'YGR075C',
#   'YPR082C',
#   'YGR091W',
#   'YBR055C'],
#  ['YKL143W',
#   'YBR181C',
#   'YGR081C',
#   'YBR247C',
#   'YDL060W',
#   'YNL207W',
#   'YPL012W',
#   'YOR056C',
#   'YBL072C'],
#  ['YCL039W',
#   'YIL097W',
#   'YMR135C',
#   'YBR105C',
#   'YBL049W',
#   'YDR255C',
#   'YIL017C',
#   'YDL176W',
#   'YGL227W'],
#  ['YNL206C',
#   'YBL008W',
#   'YJR140C',
#   'YKL160W',
#   'YOR038C',
#   'YBR010W',
#   'YOR123C',
#   'YBR215W',
#   'YPR133C'],
#  ['YJL127C',
#   'YIL084C',
#   'YAL013W',
#   'YDR295C',
#   'YCR033W',
#   'YKR029C',
#   'YOL012C',
#   'YBR103W',
#   'YPL181W'],
#  ['YHL023C',
#   'YGL100W',
#   'YJR138W',
#   'YEL062W',
#   'YBL104C',
#   'YLR208W',
#   'YKL152C',
#   'YDR128W',
#   'YOL138C'],
#  ['YOR027W',
#   'YNL007C',
#   'YDL229W',
#   'YNL064C',
#   'YAL005C',
#   'YBR169C',
#   'YLL026W',
#   'YPL106C',
#   'YPL240C'],
#  ['YLR378C',
#   'YOR254C',
#   'YPL094C',
#   'YML055W',
#   'YER087C-B',
#   'YEL031W',
#   'YLR292C',
#   'YJR117W',
#   'YBR171W'],
#  ['YCL011C',
#   'YDR064W',
#   'YLR175W',
#   'YDL208W',
#   'YGL120C',
#   'YNL308C',
#   'YOR369C',
#   'YLR430W',
#   'YHR089C'],
#  ['YAL041W',
#   'YMR032W',
#   'YPL242C',
#   'YHR023W',
#   'YNL090W',
#   'YLR425W',
#   'YDL117W',
#   'YPR165W',
#   'YBR038W'],
#  ['YBR170C',
#   'YLR207W',
#   'YGR048W',
#   'YDR411C',
#   'YIL030C',
#   'YDL126C',
#   'YBR201W',
#   'YML013W',
#   'YOL013C'],
#  ['YNL007C',
#   'YMR219W',
#   'YPL020C',
#   'YDR381W',
#   'YLL024C',
#   'YGL122C',
#   'YAL005C',
#   'YJR074W',
#   'YMR186W'],
#  ['YNL127W',
#   'YNL006W',
#   'YMR029C',
#   'YLR238W',
#   'YFR008W',
#   'YKL203C',
#   'YDR200C',
#   'YMR052W'],
#  ['YJL006C',
#   'YPL138C',
#   'YBR010W',
#   'YAR003W',
#   'YBR175W',
#   'YOR064C',
#   'YLR015W',
#   'YDR469W'],
#  ['YKL041W',
#   'YLR181C',
#   'YKL002W',
#   'YLR025W',
#   'YJL049W',
#   'YDR486C',
#   'YKR035W-A',
#   'YNL265C'],
#  ['YPL007C',
#   'YBR168W',
#   'YBR123C',
#   'YDR362C',
#   'YGR276C',
#   'YNL036W',
#   'YDR045C',
#   'YAL001C'],
#  ['YLL050C',
#   'YKL007W',
#   'YMR092C',
#   'YGR080W',
#   'YGL122C',
#   'YIL034C',
#   'YLR429W',
#   'YNL271C'],
#  ['YIL157C',
#   'YJL062W-A',
#   'Q0045',
#   'YLR203C',
#   'YPL189C-A',
#   'YML129C',
#   'YGR112W',
#   'YNL052W'],
#  ['YHR092C',
#   'YDR345C',
#   'YMR011W',
#   'YJR090C',
#   'YHR094C',
#   'YGL122C',
#   'YDR277C',
#   'YDL194W'],
#  ['YJR052W',
#   'YBL019W',
#   'YMR201C',
#   'YKL114C',
#   'YOL043C',
#   'YAL015C',
#   'YJR035W',
#   'YBR245C'],
#  ['YDL159W',
#   'YFL026W',
#   'YHR084W',
#   'YOR212W',
#   'YDR103W',
#   'YJR086W',
#   'YHR005C',
#   'YJL157C'],
#  ['YGR130C',
#   'YMR086W',
#   'YLR219W',
#   'YPL004C',
#   'YMR031C',
#   'YGL122C',
#   'YIL002C',
#   'YGR086C'],
#  ['YMR167W',
#   'YDR097C',
#   'YBR088C',
#   'YLR035C',
#   'YOL090W',
#   'YNL082W',
#   'YCR092C',
#   'YBR245C'],
#  ['YER179W',
#   'YDR285W',
#   'YPR007C',
#   'YIL072W',
#   'YHR124W',
#   'YOR351C',
#   'YBR186W',
#   'YHL022C'],
#  ['YOR208W',
#   'YER075C',
#   'YER118C',
#   'YDR420W',
#   'YGR014W',
#   'YPR075C',
#   'YCL032W',
#   'YLR113W'],
#  ['YFL009W',
#   'YOL025W',
#   'YDR328C',
#   'YOL133W',
#   'YLR079W',
#   'YDR054C',
#   'YDR139C',
#   'YDL132W'],
#  ['YKL135C',
#   'YOR299W',
#   'YKR027W',
#   'YMR237W',
#   'YBR023C',
#   'YLR330W',
#   'YJL099W',
#   'YOR104W'],
#  ['YMR296C',
#   'YOR198C',
#   'YKL126W',
#   'YDR062W',
#   'YJL134W',
#   'YGR038W',
#   'YBR058C-A',
#   'YLR350W'],
#  ['YLR052W',
#   'YBR095C',
#   'YHL027W',
#   'YDR334W',
#   'YPL139C',
#   'YNL021W',
#   'YKL032C',
#   'YNL097C'],
#  ['YER154W',
#   'YDR231C',
#   'YMR115W',
#   'YPR140W',
#   'YNR020C',
#   'YLL013C',
#   'YCL044C',
#   'YPR024W'],
#  ['YHR007C',
#   'YOR198C',
#   'YGR175C',
#   'YLR065C',
#   'YMR202W',
#   'YBR106W',
#   'YLR056W',
#   'YGR060W'],
#  ['YKR021W',
#   'YER125W',
#   'YDR099W',
#   'YGL206C',
#   'YJL084C',
#   'YOR322C',
#   'YML111W',
#   'YMR275C'],
#  ['YGR040W',
#   'YBR083W',
#   'YLR362W',
#   'YJL128C',
#   'YHR084W',
#   'YNL098C',
#   'YBL016W',
#   'YLR113W'],
#  ['YER142C', 'YLR376C', 'YDR078C', 'YHL006C', 'YIL132C', 'YDR076W', 'YDR004W'],
#  ['YOR073W', 'YFR031C', 'YLR086W', 'YBL097W', 'YLR272C', 'YJR089W', 'YDR325W'],
#  ['YHR190W', 'YHR007C', 'YER044C', 'YLR100W', 'YGL001C', 'YLR056W', 'YNL280C'],
#  ['YDL220C', 'YHL029C', 'YDR283C', 'YCR095C', 'YNL032W', 'YNL056W', 'YNL099C'],
#  ['YIR026C', 'YBL087C', 'YBL027W', 'YNL069C', 'YLR387C', 'YBR267W', 'YHR170W'],
#  ['YKL026C', 'YLR109W', 'YBL064C', 'YIR037W', 'YGL122C', 'YBR244W', 'YDR453C'],
#  ['YDL104C',
#   'YDL220C',
#   'YJL184W',
#   'YKR095W-A',
#   'YGR262C',
#   'YKR038C',
#   'YML036W'],
#  ['YLR309C', 'YDR027C', 'YJL029C', 'YLR262C', 'YDR484W', 'YKR020W', 'YBR164C'],
#  ['YLR168C', 'YLR253W', 'YLR193C', 'YAL010C', 'YOR147W', 'YGL219C', 'YHR194W'],
#  ['YHR014W',
#   'YJR021C',
#   'YHR157W',
#   'YMR133W',
#   'YER044C-A',
#   'YLR329W',
#   'YGL213C'],
#  ['YGL004C', 'YDL007W', 'YGR232W', 'YDL147W', 'YIL007C', 'YBR272C', 'YDR171W'],
#  ['YKL034W', 'YIR014W', 'YDL091C', 'YPR109W', 'YOL073C', 'YOR223W', 'YDR069C'],
#  ['YGL150C', 'YEL044W', 'YOR189W', 'YDL002C', 'YBR136W', 'YER092W', 'YNL059C'],
#  ['YLR408C', 'YNL086W', 'YGL079W', 'YDR357C', 'YEL005C', 'YNL293W', 'YKL061W'],
#  ['YDL051W', 'YPL243W', 'YML105C', 'YPR088C', 'YPL210C', 'YKL122C', 'YDL092W'],
#  ['YGL211W', 'YLR384C', 'YIL008W', 'YHR111W', 'YNL119W', 'YHR187W', 'YMR312W'],
#  ['YMR154C', 'YOR275C', 'YOR030W', 'YGL045W', 'YHL027W', 'YMR066W', 'YBR245C'],
#  ['YBR020W', 'YLR081W', 'YBR019C', 'YNL239W', 'YPL248C', 'YDR009W', 'YBR018C'],
#  ['YBR288C', 'YHR135C', 'YJL024C', 'YNL154C', 'YPL195W', 'YGR261C', 'YDR137W'],
#  ['YOL117W', 'YDR179C', 'YDL216C', 'YJR084W', 'YIL071C', 'YLR452C', 'YMR025W'],
#  ['YDR418W', 'YDL130W', 'YDR382W', 'YDL081C', 'YOL039W', 'YDR333C', 'YMR247C'],
#  ['YOR181W', 'YER093C', 'YMR068W', 'YIL105C', 'YJL058C', 'YNL047C', 'YKL203C'],
#  ['YFR011C',
#   'YCL057C-A',
#   'YNL100W',
#   'YLL009C',
#   'YKR016W',
#   'YBR262C',
#   'YGR235C'],
#  ['YBR211C',
#   'YDL028C',
#   'YJR112W',
#   'YPL233W',
#   'YER018C',
#   'YAL034W-A',
#   'YKL089W'],
#  ['YGL161C', 'YGL198W', 'YNL263C', 'YKR014C', 'YGR172C', 'YNL093W', 'YML001W'],
#  ['YGL208W', 'YDR477W', 'YDR028C', 'YER129W', 'YGL115W', 'YDR422C', 'YER027C'],
#  ['YBL032W', 'YAR050W', 'YDL233W', 'YIR019C', 'YOR140W', 'YMR164C', 'YBR245C'],
#  ['YGR180C', 'YOR230W', 'YJL026W', 'YBR136W', 'YOR229W', 'YLR437C', 'YGL016W'],
#  ['YER157W', 'YPR105C', 'YGL223C', 'YLR423C', 'YDL113C', 'YJL036W', 'YGR120C'],
#  ['YOR304W', 'YBR010W', 'YGL133W', 'YDL002C', 'YFL013C', 'YDR121W', 'YNL215W'],
#  ['YPL085W', 'YPL218W', 'YHR098C', 'YIL109C', 'YPR181C', 'YDL195W', 'YBR245C'],
#  ['YOR198C', 'YEL036C', 'YKL077W', 'YDR245W', 'YJL183W', 'YPL050C', 'YCR043C'],
#  ['YNL037C', 'YHR047C', 'YNR001C', 'YDR231C', 'YKL085W', 'YFL018C', 'YOR136W'],
#  ['YDR110W', 'YDR224C', 'YKR010C', 'YFR031C', 'YDR439W', 'YCR086W', 'YBR009C'],
#  ['YDR358W', 'YNL238W', 'YNR006W', 'YOR109W', 'YGL008C', 'YGL206C', 'YHR108W'],
#  ['YHR036W', 'YCR048W', 'YOR245C', 'YGL247W', 'YNR019W', 'YNR008W', 'YIL040W'],
#  ['YJR065C', 'YLR370C', 'YKL013C', 'YNR035C', 'YIL062C', 'YBR234C', 'YNL138W'],
#  ['YPR026W', 'YDR074W', 'YBR001C', 'YGR289C', 'YDR001C', 'YBR126C', 'YBR245C'],
#  ['YJR045C', 'YIL022W', 'YNR017W', 'YJL143W', 'YLR259C', 'YLL013C', 'YPL063W'],
#  ['YMR197C', 'YOR327C', 'YOR036W', 'YGL122C', 'YDR468C', 'YKL196C', 'YGL095C'],
#  ['YOR284W',
#   'YNL094W',
#   'YBL007C',
#   'YCR088W',
#   'YHR016C',
#   'YFR024C-A',
#   'YDR388W'],
#  ['YML016C', 'YKR050W', 'YLR138W', 'YDR436W', 'YKR072C', 'YJL129C', 'YBR245C'],
#  ['YKR007W', 'YBR077C', 'YDL123W', 'YGR163W', 'YML121W', 'YEL013W', 'YGL023C'],
#  ['YOL115W', 'YDL175C', 'YNL251C', 'YGL122C', 'YCR012W', 'YOR369C', 'YPL190C'],
#  ['YGL253W', 'YNL189W', 'YGL097W', 'YLR293C', 'YFR004W', 'YGR218W', 'YDR002W'],
#  ['YLR131C',
#   'YHR102W',
#   'YKL189W',
#   'YOR353C',
#   'YFL034C-B',
#   'YIL129C',
#   'YNL161W'],
#  ['YBR091C',
#   'YGR029W',
#   'YGL122C',
#   'YEL020W-A',
#   'YKL195W',
#   'YLL013C',
#   'YHR005C-A'],
#  ['YJL053W', 'YOR132W', 'YJL154C', 'YHR012W', 'YPL070W', 'YBR164C', 'YOR069W'],
#  ['YIL153W', 'YPL152W', 'YDL188C', 'YAL016W', 'YMR028W', 'YDL134C', 'YOR014W'],
#  ['YGL012W', 'YPL057C', 'YMR272C', 'YBR161W', 'YDR297W', 'YOR171C', 'YBR036C'],
#  ['YEL061C', 'YCL029C', 'YER007W', 'YPL155C', 'YGL216W', 'YFL037W', 'YML085C'],
#  ['YOL006C', 'YLR154C', 'YNL072W', 'YOR033C', 'YMR234W', 'YDR279W', 'YER070W'],
#  ['YDL029W', 'YIR006C', 'YNL020C', 'YNL243W', 'YNL084C', 'YGR241C', 'YIL095W'],
#  ['YDR390C', 'YOR156C', 'YER116C', 'YPR180W', 'YDL013W', 'YDL059C', 'YDL064W'],
#  ['YOL054W', 'YOR061W', 'YOR039W', 'YIL035C', 'YGL019W', 'YDR168W', 'YER161C'],
#  ['YDL226C', 'YAL026C', 'YER031C', 'YGL210W', 'YDL192W', 'YNL267W', 'YCR094W'],
#  ['YBR143C',
#   'YER165W',
#   'YMR080C',
#   'YCR024C-A',
#   'YDR172W',
#   'YMR116C',
#   'YJL080C'],
#  ['YMR238W', 'YGR229C', 'YMR307W', 'YKL190W', 'YDL006W', 'YNL322C', 'YDR182W'],
#  ['YMR077C', 'YLR417W', 'YGL167C', 'YBR290W', 'YLR025W', 'YPR173C', 'YCL008C'],
#  ['YNL006W', 'YJR066W', 'YHR186C', 'YLR377C', 'YKL203C', 'YPL180W', 'YGL023C'],
#  ['YBR034C', 'YOR070C', 'YNL041C', 'YER083C', 'YNL051W', 'YGR105W', 'YGR106C'],
#  ['YPL084W', 'YNL159C', 'YDR160W', 'YMR119W', 'YNL008C', 'YFR029W'],
#  ['YGR033C', 'YIL022W', 'YJL143W', 'YJL104W', 'YML054C', 'YLR008C'],
#  ['YLR141W', 'YBL025W', 'YBR010W', 'YMR270C', 'YBR009C', 'YOR295W'],
#  ['YLR210W', 'YBR160W', 'YDL155W', 'YGR108W', 'YLR079W', 'YBR135W'],
#  ['YLR180W', 'YOL040C', 'YGL123W', 'YHR169W', 'YDR502C', 'YLR153C'],
#  ['YMR185W', 'YER159C', 'YOR151C', 'YDR397C', 'YGL122C', 'YDL115C'],
#  ['YOL111C', 'YMR292W', 'YDL100C', 'YOR007C', 'YBR137W', 'YOR164C'],
#  ['YNL225C', 'YKL042W', 'YOR373W', 'YDL239C', 'YOL091W', 'YOR177C'],
#  ['YNR038W', 'YOL144W', 'YLR221C', 'YML093W', 'YJR041C', 'YKL014C'],
#  ['YBL103C', 'YJL127C', 'YIR023W', 'YDR216W', 'YBR010W', 'YDR146C'],
#  ['YBR128C', 'YLR360W', 'YPL120W', 'YLR211C', 'YLR240W', 'YBR097W'],
#  ['YHR034C', 'YHR040W', 'YJR055W', 'YPL193W', 'YOR310C', 'YEL026W'],
#  ['YBR211C', 'YGR179C', 'YDR113C', 'YDL139C', 'YCR065W', 'YPL017C'],
#  ['YPL066W', 'YLR110C', 'YHR030C', 'YBL061C', 'YJL159W', 'YNL233W'],
#  ['YBR145W', 'YMR083W', 'YMR303C', 'YGL256W', 'YDL168W', 'YOL086C'],
#  ['YLR417W', 'YDR043C', 'YPL065W', 'YPL002C', 'YJR102C', 'YGR206W'],
#  ['YDR165W', 'YLR401C', 'YDL201W', 'YOR274W', 'YBL024W', 'YOR243C'],
#  ['YMR094W', 'YBR211C', 'YJR060W', 'YMR168C', 'YGR140W', 'YBR245C'],
#  ['YBR181C', 'YOL041C', 'YMR269W', 'YDR083W', 'YCR031C', 'YNL135C'],
#  ['YKL181W', 'YOL061W', 'YHL011C', 'YOL069W', 'YER099C', 'YBL068W'],
#  ['YFL060C', 'YNL333W', 'YMR095C', 'YNL334C', 'YFL059W', 'YMR096W'],
#  ['YLR354C', 'YJL121C', 'YNL241C', 'YGL148W', 'YGR043C', 'YGL122C'],
#  ['YCL014W', 'YCR038C', 'YJR092W', 'YLR353W', 'YIL140W', 'YBR245C'],
#  ['YML006C', 'YDR477W', 'YLR094C', 'YOR360C', 'YNL025C', 'YGL035C'],
#  ['YNL224C', 'YKL078W', 'YOR287C', 'YDL153C', 'YLR336C', 'YGR251W'],
#  ['YOR198C', 'YDL212W', 'YPL265W', 'YKR039W', 'YBR068C', 'YDR508C'],
#  ['YBR181C', 'YLR432W', 'YOR004W', 'YKL204W', 'YBL072C', 'YML056C'],
#  ['YAL044W-A', 'YPL059W', 'YDR098C', 'YER174C', 'YGL122C', 'YAL046C'],
#  ['YBR159W', 'YOR198C', 'YDL015C', 'YCR034W', 'YLR372W', 'YJL097W'],
#  ['YOR198C', 'YEL046C', 'YBR263W', 'YDR019C', 'YOR184W', 'YLR058C'],
#  ['YNL038W', 'YLR088W', 'YPL096C-A', 'YHR188C', 'YBR004C', 'YOR336W'],
#  ['YPL135W', 'YCL017C', 'YLR369W', 'YDL120W', 'YLL013C', 'YJR104C'],
#  ['YDR153C', 'YLR398C', 'YPR189W', 'YOR076C', 'YJR089W', 'YGL213C'],
#  ['YAL041W', 'YGR152C', 'YER114C', 'YOL070C', 'YBL085W', 'YPL158C'],
#  ['YBL105C', 'YLR332W', 'YGR196C', 'YDL203C', 'YOR231W', 'YBR260C'],
#  ['YBL015W', 'YER178W', 'YNL071W', 'YKR016W', 'YCR005C', 'YBR221C'],
#  ['YER125W', 'YBR082C', 'YDR177W', 'YER100W', 'YMR022W', 'YDR059C'],
#  ['YBR041W', 'YHR072W', 'YKL140W', 'YBR177C', 'YLR144C', 'YLL012W'],
#  ['YKL048C', 'YNL027W', 'YOR276W', 'YLR433C', 'YDR207C', 'YML057W'],
#  ['YDR049W', 'YDL190C', 'YBL058W', 'YDL126C', 'YFL044C', 'YKL213C'],
#  ['YMR232W', 'YER149C', 'YCL027W', 'YGR238C', 'YIL159W', 'YHR158C'],
#  ['YEL037C', 'YMR276W', 'YDL227C', 'YHR027C', 'YER143W', 'YGL178W'],
#  ['YDR309C', 'YML109W', 'YAL024C', 'YHR149C', 'YMR273C', 'YHR061C'],
#  ['YGR209C', 'YML007W', 'YJL156C', 'YDR160W', 'YIR037W', 'YFR029W'],
#  ['YPR152C', 'YHR174W', 'YBR194W', 'YBL072C', 'YGR254W', 'YOL086C'],
#  ['YDR291W', 'YNL002C', 'YGR159C', 'YGL078C', 'YKL014C', 'YLR276C'],
#  ['YKR001C', 'YBR179C', 'YKR036C', 'YLL001W', 'YJL112W', 'YIL065C'],
#  ['YAL038W', 'YHR047C', 'YPR042C', 'YLR304C', 'YJR016C', 'YBR118W'],
#  ['YPL031C', 'YOL001W', 'YGR233C', 'YML123C', 'YHR071W', 'YFR034C'],
#  ['YOR197W', 'YNL112W', 'YMR116C', 'YHR193C', 'YNL209W', 'YNL026W'],
#  ['YOR122C', 'YKL033W', 'YGR099W', 'YJR136C', 'YPR085C', 'YFL039C']]

# %%
ire1 = "YHR079C"
kar2 = "YJL034W"
yos9 = "YDR057W"
hac1 = "YFL031W"

# %% [markdown]
# ## Create Cluster Graph

# %%
def cluster_weight(cluster1, cluster2, G):
    # Number of connected pairs / number of pairs in total
    total_num = len(cluster1) * len(cluster2)
    connected_num = 0.0
    for node1 in cluster1:
        for node2 in cluster2:
            if (node1, node2) in G.edges:
                connected_num += 1
    return connected_num / total_num

# %%
cluster_weight(clusters[0], clusters[3], G_exp)
# Out:
# 0.0244173140954495

# %%
cluster_graph = nx.Graph()

# %%
cluster_weighted_edges = []

# Assume clusters are sorted
for i in range(len(clusters)):
    for j in range(i+1, len(clusters)):
        cluster_weighted_edges.append((i, j, cluster_weight(clusters[i], clusters[j], G_exp)))

# %%
cluster_graph.add_weighted_edges_from(cluster_weighted_edges)

# %% [markdown]
# ## Find IRE1 Cluster

# %%
ire_clusters = []

for i in range(len(clusters)):
    if ire1 in clusters[i]:
        ire_clusters.append(i)
        
print(ire_clusters)
# Out:
# [73]

# %%
ire_weights = []
ire_cluster = ire_clusters[0]

for i in range(len(clusters)):
    if i == ire_cluster:
        continue
    else:
        ire_weight = cluster_graph[i][ire_cluster]['weight']
        ire_weights.append((i, ire_weight))

# %%
ire_weights.sort(key=lambda x: x[1], reverse=True)

# %%
top_5_ire_indexes = [tup[0] for tup in ire_weights[:5]]

# %%
top_5_ire_indexes
# Out:
# [70, 164, 67, 26, 61]

# %%
top_5_ire_clusters = [clusters[i] for i in top_5_ire_indexes]

# %%
for cluster in top_5_ire_clusters:
    print(','.join(cluster))
# Out:
# YHR030C,YDL095W,YBR015C,YAL023C,YJL062W,YGL027C,YGR166W,YBR229C,YML019W,YCR017C
# YMR238W,YGR229C,YMR307W,YKL190W,YDL006W,YNL322C,YDR182W
# YAL058W,YDR414C,YMR200W,YBR015C,YHR101C,YJR075W,YJL034W,YMR214W,YBR229C,YOR336W
# YOR085W,YOR002W,YGL226C-A,YFL031W,YOR067C,YOR103C,YPL227C,YGR227W,YJL002C,YMR149W,YGL022W,YEL002C,YBL082C,YNR030W,YML019W,YNL219C
# YLR212C,YOR008C,YDR293C,YBL032W,YHR030C,YBR160W,YBL105C,YNL298W,YNL188W,YJL095W,YER111C

# %% [markdown]
# ## HAC1 Clusters

# %%
hac_clusters = []

for i in range(len(clusters)):
    if hac1 in clusters[i]:
        hac_clusters.append(i)
        
hac_cluster = hac_clusters[0]
print(hac_cluster)

hac_weights = []

for i in range(len(clusters)):
    if i == hac_cluster:
        continue
    else:
        hac_weight = cluster_graph[i][hac_cluster]['weight']
        hac_weights.append((i, hac_weight))
        
hac_weights.sort(key=lambda x: x[1], reverse=True)

top_5_hac_indexes = [tup[0] for tup in hac_weights[:5]]
print(top_5_hac_indexes)
top_5_hac_clusters = [clusters[i] for i in top_5_hac_indexes]
for cluster in top_5_hac_clusters:
    print(','.join(cluster))
# Out:
# 26
# [70, 73, 67, 81, 164]
# YHR030C,YDL095W,YBR015C,YAL023C,YJL062W,YGL027C,YGR166W,YBR229C,YML019W,YCR017C
# YFL025C,YHR030C,YML008C,YFL031W,YMR307W,YJR073C,YGR167W,YGL084C,YCR044C,YHR079C
# YAL058W,YDR414C,YMR200W,YBR015C,YHR101C,YJR075W,YJL034W,YMR214W,YBR229C,YOR336W
# YLR378C,YOR254C,YPL094C,YML055W,YER087C-B,YEL031W,YLR292C,YJR117W,YBR171W
# YMR238W,YGR229C,YMR307W,YKL190W,YDL006W,YNL322C,YDR182W

# %% [markdown]
# ## KAR2 Clusters

# %%
kar_clusters = []

for i in range(len(clusters)):
    if kar2 in clusters[i]:
        kar_clusters.append(i)

kar_cluster = hac_clusters[0]
print(kar_cluster)
kar_weights = []

for i in range(len(clusters)):
    if i == kar_cluster:
        continue
    else:
        kar_weight = cluster_graph[i][kar_cluster]['weight']
        kar_weights.append((i, kar_weight))
        
kar_weights.sort(key=lambda x: x[1], reverse=True)

top_5_kar_indexes = [tup[0] for tup in kar_weights[:5]]
print(top_5_kar_indexes)
top_5_kar_clusters = [clusters[i] for i in top_5_kar_indexes]
for cluster in top_5_kar_clusters:
    print(','.join(cluster))
# Out:
# 26
# [70, 73, 67, 81, 164]
# YHR030C,YDL095W,YBR015C,YAL023C,YJL062W,YGL027C,YGR166W,YBR229C,YML019W,YCR017C
# YFL025C,YHR030C,YML008C,YFL031W,YMR307W,YJR073C,YGR167W,YGL084C,YCR044C,YHR079C
# YAL058W,YDR414C,YMR200W,YBR015C,YHR101C,YJR075W,YJL034W,YMR214W,YBR229C,YOR336W
# YLR378C,YOR254C,YPL094C,YML055W,YER087C-B,YEL031W,YLR292C,YJR117W,YBR171W
# YMR238W,YGR229C,YMR307W,YKL190W,YDL006W,YNL322C,YDR182W

# %%
top_5_overall = list(set(top_5_ire_indexes + top_5_hac_indexes + top_5_kar_indexes))

# %%
clusters[70]
# Out:
# ['YHR030C',
#  'YDL095W',
#  'YBR015C',
#  'YAL023C',
#  'YJL062W',
#  'YGL027C',
#  'YGR166W',
#  'YBR229C',
#  'YML019W',
#  'YCR017C']

# %% [markdown]
# ## Draw Cluster Graph

# %%
cluster_network = pyvis.network.Network(notebook = True, bgcolor="#222222", font_color="white")

# Set up nodes and edges

cluster_network.inherit_edge_colors(False)

for node in top_5_overall:
    cluster_network.add_node(node, label=str(node))
    if (node == 73):
        cluster_network.get_node(73)['label'] = "IRE1"
    if (node == 26):
        cluster_network.get_node(26)['label'] = "HAC1/KAR2"
    if (node == 70):
        cluster_network.get_node(70)['label'] = "Nearest cluster"

# Add edges
for i in range(len(top_5_overall)):
    for j in range(i):
        n1 = top_5_overall[i]
        n2 = top_5_overall[j]
        cluster_network.add_edge(top_5_overall[i], top_5_overall[j], value=cluster_graph[n1][n2]['weight'], title = str(round(cluster_graph[n1][n2]['weight'], 2)), color='#9EC3F7')


# Highlight specific nodes

cluster_network.get_node(70)['color'] = "#07f507" # Desired cluster

cluster_network.get_node(73)['color'] = "#e33a02" # IRE1
cluster_network.get_node(26)['color'] = "#f2f25c" # HAC1 + KAR2

# Physics parameters
cluster_network.barnes_hut(gravity = -4000)
cluster_network.show("cluster.html", local=False, notebook=True)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# cluster.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="cluster.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
